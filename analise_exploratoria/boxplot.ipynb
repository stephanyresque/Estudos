# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

PATH = r"C:\Users\steph\OneDrive\Documentos\MeusProjetos\Estudos\analise_exploratoria\dados\trees.csv"
df = pd.read_csv(PATH)

# %%
df.head()
# Out:
#    Girth  Height  Volume
# 0    8.3      70    10.3
# 1    8.6      65    10.3
# 2    8.8      63    10.2
# 3   10.5      72    16.4
# 4   10.7      81    18.8

# %%
plt.boxplot(
    df.Volume, vert = False, showfliers = False,
    notch = True, patch_artist = True
)

plt.title("Árvores")
plt.xlabel("Volume")
plt.show()

# %%
plt.boxplot(
    df.Volume, vert = False, showfliers = True,
    notch = False, patch_artist = True
)

plt.title("Árvores")
plt.xlabel("Volume")
plt.show()

# %%
plt.boxplot(df)
plt.title("Árvroes")
plt.xlabel("Dados")

plt.show()

# %%
sns.boxplot(data = df.Volume, orient = "v").set_title("Árvores");

# %%
sns.boxplot(data = df)
# Out:
# <Axes: >
