# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

PATH = r"C:\Users\steph\OneDrive\Documentos\MeusProjetos\Estudos\analise_exploratoria\dados\trees.csv"

# %%
df = pd.read_csv(PATH)

# %%
df.shape
# Out:
# (31, 3)

# %%
df.head()
# Out:
#    Girth  Height  Volume
# 0    8.3      70    10.3
# 1    8.6      65    10.3
# 2    8.8      63    10.2
# 3   10.5      72    16.4
# 4   10.7      81    18.8

# %%
h = np.histogram(df.iloc[:,1], bins=6)

h
# Out:
# (array([4, 2, 5, 7, 9, 4]), array([63., 67., 71., 75., 79., 83., 87.]))

# %%
plt.hist(df.iloc[:,1], bins = 6)
plt.title("Árvores")
plt.ylabel("Frequência")
plt.xlabel("Altura")
# Out:
# Text(0.5, 0, 'Altura')

# %%
plt.hist(df.iloc[:,1], bins = 10)
plt.title("Árvores")
plt.ylabel("Frequência")
plt.xlabel("Altura")
# Out:
# Text(0.5, 0, 'Altura')

# %%
sns.histplot(df.iloc[:,1], bins=6, color = 'pink', kde='True').set_title("Árvores")
# Out:
# Text(0.5, 1.0, 'Árvores')

# %%
sns.kdeplot(df.iloc[:,1], color = 'purple').set_title("Árvores")
# Out:
# Text(0.5, 1.0, 'Árvores')
